# %% [markdown]
# <a href="https://colab.research.google.com/github/longyoujun/115-1/blob/main/411414753_H1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello\nhello")
# Out:
# hello
# hello

# %%
a=2.5
b=5
c="python"
print(type(c))
# Out:
# <class 'str'>

# %%
from re import X
x=5
y=2
temp=x
x=y
y=temp
print(x,y)
# Out:
# 2 5

# %%
t=5
h=5
print(id(h))
# Out:
# 10446536

# %%
x=50000*(1+0.015)**5
print(x)
# Out:
# 53864.20019421873
