# %% [markdown]
# <a href="https://colab.research.google.com/github/longyoujun/115-1/blob/main/411414753_H2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
m=int(input("請輸入目前金幣數量:"))
n=int(input("請輸入獲得金幣數量:"))
i=m+n
print(f"任務完成!你現在有{i}枚金幣")
# Out:
# 請輸入目前金幣數量:500
# 請輸入獲得金幣數量:250
# 任務完成!你現在有750枚金幣
